# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
MEX = 1e3
x = []
y = []
for i in range(10000,10000+int(MEX)):
    cnt = 0
    x.append(i)
    for k in range(1,i+1):
        if i % k == 0:
            cnt = cnt+1
    y.append(cnt)

plt.plot(x,y)
print(max(y))
# Out:
# 72
